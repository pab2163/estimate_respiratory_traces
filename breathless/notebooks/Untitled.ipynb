# %%
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filt = np.genfromtxt("./sub-A00053576_ses-BAS1_task-rest_acq-1400_bold_filtered.1D")

# %%
plt.plot(filt)
